# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomasz-Rac/Modul-7/blob/master/Zadanie%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy_financial as npf

freq = 12
rate_up = 0.05
rate = 0.12
years = 5
pv = 120000

miesiace = np.arange(0, years * freq + 1)

wartosc_mieszkania = pv * (1 + rate_up) ** (miesiace / freq)

cena_up =round(pv * (1+ rate_up)**years ,2)

print(cena_up)

r_m = rate / freq

p = round(cena_up * (r_m / ((1 + r_m)**(freq * years) -1)),2)
print(p)

wartosc_lokaty = np.zeros(len(miesiace))
for i in range(1, len(miesiace)):
    wartosc_lokaty[i] = wartosc_lokaty[i - 1] * (1 + r_m) + p

plt.figure(figsize=(10, 5))
plt.plot(miesiace, wartosc_mieszkania, label="Wartość mieszkania", color='b', linestyle='--', marker='o')
plt.plot(miesiace, wartosc_lokaty, label="Wartość lokaty", color='g', linestyle='-', marker='s')

plt.xlabel("Liczba miesięcy")
plt.ylabel("Wartość (PLN)")
plt.title("Zmiana wartości mieszkania i lokaty w czasie")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# 153153.79
# 1875.28
